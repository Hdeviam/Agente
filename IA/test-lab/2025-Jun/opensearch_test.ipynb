# %%
import sys
import os
# Ruta al proyecto (ajusta si estás en otra carpeta)
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(project_root)

from opensearchpy import OpenSearch, RequestsHttpConnection
from requests_aws4auth import AWS4Auth
import boto3
import os
from app.core.config import AWS_REGION

# %%
OPENSEARCH_HOST= 'https://search-housy-search-ulrry5a5bl4vy2huqdq7j2uu5e.us-east-1.es.amazonaws.com'

# %%
from app.core.aws_clients import get_opensearch_client

# %%
client = get_opensearch_client()

# %%
from app.services.embeddings.search_opensearch import search_similar_properties

# %%
response = search_similar_properties("Propiedad en lima con 3 habitaciones, ")
# Out:
# DEBUG: Resultados de búsqueda crudos: [{'text': 'Moderno y confortable departamento en Lima - Aprovecha este excelente departamento moderno, situado en un barrio tranquilo de Lima. Se ofrece una vista hermosa desde el balcón, y todo el equipo es reciente y de calidad. - mini-departamento - Avenida General Trinidad Morán, Risso, Lince, Lima, Lima Metropolitana, Lima, 51015, Perú - alquiler', 'score': 0.0049309125}, {'text': 'Apartamento moderno y cómodo en Lima Metropolitana - Bienvenido a este espacio moderno e iluminado, situado en la tranquila Avenida Horacio Urteaga de Santa Beatriz. Equipado con todas las comodidades necesarias para vivir confortablemente. - cuarto - Avenida Horacio Urteaga, Santa Beatriz, Jesús María, Lima, Lima Metropolitana, Lima, 15083, Perú - alquiler', 'score': 0.0048992415}, {'text': 'Confortable y moderno departamento en Comas, Lima - Áticos 3º piso con vistas panorámicas, moderno diseño e iluminación natural. Ubicado en el corazón de Comas, Lima Metropol
# ...

# %% [markdown]
# # embedder test

# %%
from app.services.embeddings.bedrock_service import embed_text

# %%
test = embed_text("Comencemos con esta prueba de embedding")
test
# Out:
# [0.462890625,
#  0.18359375,
#  0.58203125,
#  0.7734375,
#  -0.60546875,
#  0.5546875,
#  -0.2578125,
#  -0.00017547607421875,
#  -0.298828125,
#  -0.1044921875,
#  0.66015625,
#  -0.0810546875,
#  0.359375,
#  0.3125,
#  -0.65234375,
#  -0.11865234375,
#  0.1220703125,
#  0.18359375,
#  -0.62890625,
#  0.482421875,
#  -0.12890625,
#  0.1748046875,
#  -0.1787109375,
#  0.08203125,
#  -0.0028076171875,
#  -0.28125,
#  -0.69921875,
#  0.0166015625,
#  0.453125,
#  -0.34765625,
#  -0.49609375,
#  -0.328125,
#  0.09130859375,
#  -0.26953125,
#  0.054443359375,
#  -0.27734375,
#  0.71875,
#  0.13671875,
#  -0.494140625,
#  0.2353515625,
#  0.50390625,
#  -0.421875,
#  0.71484375,
#  0.2734375,
#  0.341796875,
#  0.640625,
#  0.10205078125,
#  -0.04541015625,
#  0.52734375,
#  0.66796875,
#  0.07470703125,
#  0.65234375,
#  -0.23828125,
#  0.09423828125,
#  0.294921875,
#  0.1279296875,
#  0.046875,
#  0.28515625,
#  0.318359375,
#  0.384765625,
#  -0.890625,
#  0.34375,
#  -0.609375,
# ...
